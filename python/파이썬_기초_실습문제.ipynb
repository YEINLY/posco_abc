# %% [markdown]
# # 파이썬 기초 실습 문제집
# ## 섹션 1~9 종합 실습
#
# > 각 문제를 읽고 `# TODO` 부분에 코드를 작성하세요.
# > 정답 확인은 각 셀 아래 주석을 참고하세요.

# %% [markdown]
# ---
# ## 섹션 1. 출력문 (print)

# %% [markdown]
# ### 문제 1-1
# 아래 변수들을 사용해서 `"안녕하세요! 저는 조예찬이고, 나이는 28살입니다."` 형태로 출력하세요.
# (f-string 사용)

# %%
name = "조예찬"
age = 28

# TODO: f-string으로 출력하세요.

# %% [markdown]
# > 💡 정답 예시: `print(f"안녕하세요! 저는 {name}이고, 나이는 {age}살입니다.")`

# %% [markdown]
# ### 문제 1-2
# `"="` 를 50번 반복 출력하고, 가운데 줄에 `"파이썬 실습"` 을 출력한 뒤, 다시 `"="` 50개를 출력하세요.

# %%
# TODO: 3줄로 출력하세요.

# %% [markdown]
# ### 문제 1-3 (빈칸 채우기)
# 아래 코드가 `"Hello, World!"` 를 출력하도록 빈칸을 채우세요.

# %%
greeting = "Hello"
target = "World"

print(___ + ", " + ___ + "!")

# %% [markdown]
# ---
# ## 섹션 2. 자료형

# %% [markdown]
# ### 문제 2-1
# 아래 값들의 자료형을 `type()` 으로 출력하세요.
# - `42`
# - `3.14`
# - `"파이썬"`
# - `True`

# %%
# TODO: 4개 값 각각 type() 출력

# %% [markdown]
# ### 문제 2-2 (리스트 슬라이싱)
# `fruits` 리스트에서 인덱싱/슬라이싱을 이용해 아래를 출력하세요.
# 1. 첫 번째 과일
# 2. 마지막 과일
# 3. 두 번째부터 네 번째까지 (3개)

# %%
fruits = ["사과", "바나나", "포도", "딸기", "수박"]

# 1) 첫 번째 과일
print(___)

# 2) 마지막 과일
print(___)

# 3) 두 번째~네 번째 (인덱스 1~3)
print(___)

# %% [markdown]
# ---
# ## 섹션 3. 주석과 변수

# %% [markdown]
# ### 문제 3-1
# 원의 반지름 `r = 5` 일 때, 원의 넓이와 둘레를 계산해서 출력하세요.
# - 넓이 = π × r²  (`pi = 3.14159` 사용)
# - 둘레 = 2 × π × r

# %%
pi = 3.14159
r = 5

# TODO: 넓이와 둘레를 각각 계산하고 출력
area = ___
perimeter = ___

print(f"원의 넓이: {area}")
print(f"원의 둘레: {perimeter}")

# %% [markdown]
# ### 문제 3-2 (빈칸 채우기)
# 세 변수를 이용해 `z = 30` 이 되도록 빈칸을 채우세요.

# %%
a = 3
b = 4
c = 2

z = a * ___ + ___   # z == 30 이 되도록

print(z)  # 30 출력 확인

# %% [markdown]
# ---
# ## 섹션 4. 입력문과 형변환

# %% [markdown]
# ### 문제 4-1
# 사용자에게 이름과 나이를 입력받아 아래 형태로 출력하세요.
# ```
# 안녕하세요, [이름]님! 내년에는 [나이+1]살이 되시네요.
# ```
# (나이는 정수로 형변환 필요)

# %%
# name = input("이름을 입력하세요: ")
# age_str = input("나이를 입력하세요: ")

# TODO: age_str을 정수로 변환 후 출력
# age = ___
# print(f"안녕하세요, {name}님! 내년에는 {age + 1}살이 되시네요.")

# %% [markdown]
# ### 문제 4-2 (BMI 계산기)
# 키(cm)와 몸무게(kg)를 입력받아 BMI를 계산하세요.
# BMI = 몸무게(kg) ÷ 키(m)²

# %%
# height_cm = input("키(cm): ")
# weight_kg = input("몸무게(kg): ")

# TODO: 형변환 후 BMI 계산
# height_m = float(height_cm) / 100
# weight = float(weight_kg)
# bmi = ___
# print(f"BMI: {bmi:.1f}")

# %% [markdown]
# ---
# ## 섹션 5. 논리형, 비교·논리 연산자

# %% [markdown]
# ### 문제 5-1
# 아래 표현식의 결과를 먼저 손으로 예측한 뒤, 코드를 실행해 확인하세요.

# %%
a = 10
b = 3
c = 10

# 예측 → True / False ?
print(a == c)           # ?
print(a != b)           # ?
print(b > 5 or a < 20)  # ?
print(a > 5 and b > 5)  # ?
print(not (a == b))     # ?

# %% [markdown]
# ### 문제 5-2 (빈칸 채우기)
# `score = 75` 일 때 아래 두 표현식이 모두 `True` 가 되도록 빈칸에 비교 연산자를 넣으세요.

# %%
score = 75

expr1 = (score ___ 70) and (score ___ 80)   # 70 초과 80 미만
expr2 = (score ___ 60) or (score ___ 100)   # 60 이상 또는 100 미만

print(expr1)  # True
print(expr2)  # True

# %% [markdown]
# ---
# ## 섹션 6. 조건문

# %% [markdown]
# ### 문제 6-1 (학점 계산기)
# `score` 를 받아 아래 기준으로 학점을 출력하는 코드를 작성하세요.
#
# | 점수 | 학점 |
# |------|------|
# | 90 이상 | A |
# | 80 이상 | B |
# | 70 이상 | C |
# | 60 이상 | D |
# | 60 미만 | F |

# %%
score = 73  # 이 값을 바꿔가며 테스트해 보세요.

# TODO: if ~ elif ~ else 로 학점 출력

# %% [markdown]
# ### 문제 6-2 (홀짝 & 양음수 판별)
# 정수 `n` 을 받아 두 가지를 동시에 출력하세요.
# 1. 양수 / 음수 / 0
# 2. 홀수 / 짝수 (0은 짝수로 처리)

# %%
n = -7  # 이 값을 바꿔가며 테스트해 보세요.

# TODO: 조건문 두 세트 작성

# %% [markdown]
# ### 문제 6-3 (자판기)
# `money` 와 `item_price` 가 주어질 때:
# - 잔액이 충분하면 `"구매 완료! 잔액: [거스름돈]원"` 출력
# - 부족하면 `"잔액 부족! [부족액]원이 더 필요합니다."` 출력

# %%
money = 1000
item_price = 1500

# TODO:

# %% [markdown]
# ---
# ## 섹션 7. 반복문

# %% [markdown]
# ### 문제 7-1 (구구단)
# `dan` 에 해당하는 구구단을 출력하세요.
# 예) `dan = 3` → `3 x 1 = 3` ~ `3 x 9 = 27`

# %%
dan = 3

# TODO: for + range 사용

# %% [markdown]
# ### 문제 7-2 (리스트 합계)
# `numbers` 리스트의 모든 값을 더한 합계를 `for` 문으로 구하세요.
# (내장 함수 `sum()` 사용 금지)

# %%
numbers = [10, 25, 3, 47, 8, 16]
total = 0

# TODO: for 문으로 합계 구하기

print("합계:", total)  # 109

# %% [markdown]
# ### 문제 7-3 (while + break)
# 1부터 시작해서 숫자를 더해가다가, 누적 합이 처음으로 50을 넘는 순간 멈추고
# `"숫자: __, 누적 합: __"` 을 출력하세요.

# %%
i = 1
total = 0

# TODO: while True + break 사용

# %% [markdown]
# ### 문제 7-4 (빈칸 채우기)
# 아래 코드가 1~10 사이 짝수만 출력하도록 빈칸을 채우세요.

# %%
for i in range(___, ___, ___):
    print(i)

# 출력: 2 4 6 8 10

# %% [markdown]
# ---
# ## 섹션 8. 함수와 메서드

# %% [markdown]
# ### 문제 8-1
# 두 수를 받아 더 큰 수를 반환하는 함수 `my_max(a, b)` 를 작성하세요.
# (내장 함수 `max()` 사용 금지)

# %%
def my_max(a, b):
    # TODO:
    pass

print(my_max(3, 7))   # 7
print(my_max(10, 2))  # 10

# %% [markdown]
# ### 문제 8-2
# 섭씨 온도를 화씨로 변환하는 함수 `celsius_to_fahrenheit(c)` 를 작성하세요.
# 공식: `F = C × 9/5 + 32`

# %%
def celsius_to_fahrenheit(c):
    # TODO:
    pass

print(celsius_to_fahrenheit(0))    # 32.0
print(celsius_to_fahrenheit(100))  # 212.0

# %% [markdown]
# ### 문제 8-3 (문자열 메서드)
# 문자열 `s` 에 대해 아래를 출력하세요.
# 1. 대문자로 변환
# 2. 공백 기준으로 단어 분리 (리스트)
# 3. `"python"` 이 몇 번 등장하는지

# %%
s = "hello python, welcome to python world"

# 1) 대문자
print(___)

# 2) 단어 리스트
print(___)

# 3) "python" 등장 횟수
print(___)

# %% [markdown]
# ### 문제 8-4 (빈칸 채우기)
# 리스트를 받아 최솟값을 반환하는 함수를 완성하세요.

# %%
def my_min(lst):
    result = lst[0]
    for num in ___:
        if num ___ result:
            result = ___
    return result

print(my_min([5, 2, 8, 1, 9]))  # 1

# %% [markdown]
# ---
# ## 섹션 9. 클래스와 객체

# %% [markdown]
# ### 문제 9-1
# `Student` 클래스를 만드세요.
# - 속성: `name`, `score`
# - 메서드: `grade()` → 점수에 따라 A/B/C/D/F 반환

# %%
class Student:
    def __init__(self, name, score):
        # TODO:
        pass

    def grade(self):
        # TODO: 90이상 A, 80이상 B, 70이상 C, 60이상 D, 나머지 F
        pass

s1 = Student("조예찬", 85)
s2 = Student("홍길동", 55)

print(f"{s1.name}: {s1.grade()}")  # 조예찬: B
print(f"{s2.name}: {s2.grade()}")  # 홍길동: F

# %% [markdown]
# ### 문제 9-2
# `Calculator` 클래스를 만드세요.
# - 속성: `result` (초기값 0)
# - 메서드:
#   - `add(n)`: result에 n 더하기
#   - `subtract(n)`: result에서 n 빼기
#   - `reset()`: result를 0으로 초기화
#   - `show()`: 현재 result 출력

# %%
class Calculator:
    def __init__(self):
        # TODO:
        pass

    def add(self, n):
        # TODO:
        pass

    def subtract(self, n):
        # TODO:
        pass

    def reset(self):
        # TODO:
        pass

    def show(self):
        # TODO:
        pass

# 테스트
calc = Calculator()
calc.add(10)
calc.add(5)
calc.show()        # 15
calc.subtract(3)
calc.show()        # 12
calc.reset()
calc.show()        # 0
